# %%
import pandas as pd

# %%
df = pd.read_csv('data/unemployment/OECD.SDD.TPS,DSD_LFS@DF_IALFS_INDIC,1.0+GBR+JPN+ITA+DEU+FRA+CAN+USA.UNE_LF_M...Y._T.Y_GE15..M.csv')
df
# Out:
#      STRUCTURE                              STRUCTURE_ID  \
# 0     DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 1     DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 2     DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 3     DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 4     DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# ...        ...                                       ...
# 4406  DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 4407  DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 4408  DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 4409  DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
# 4410  DATAFLOW  OECD.SDD.TPS:DSD_LFS@DF_IALFS_INDIC(1.0)
#
#                       STRUCTURE_NAME ACTION REF_AREA  Reference area  \
# 0     Infra-annual labour statistics      I      JPN           Japan
# 1     Infra-annual labour statistics      I      JPN           Japan
# 2     Infra-annual labour statistics      I      JPN           Japan
# ...

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Reference area', 'MEASURE', 'Measure', 'UNIT_MEASURE',
#        'Unit of measure', 'TRANSFORMATION', 'Transformation', 'ADJUSTMENT',
#        'Adjustment', 'SEX', 'Sex', 'AGE', 'Age', 'ACTIVITY',
#        'Economic activity', 'FREQ', 'Frequency of observation', 'TIME_PERIOD',
#        'Time period', 'OBS_VALUE', 'Observation value', 'BASE_PER',
#        'Base period', 'OBS_STATUS', 'Observation status', 'UNIT_MULT',
#        'Unit multiplier', 'DECIMALS', 'Decimals'],
#       dtype='object')

# %%
df['Base period']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4406   NaN
# 4407   NaN
# 4408   NaN
# 4409   NaN
# 4410   NaN
# Name: Base period, Length: 4411, dtype: float64

# %%
df = df[['TIME_PERIOD', 'Reference area', 'OBS_VALUE']]

# %%
df
# Out:
#      TIME_PERIOD  Reference area  OBS_VALUE
# 0        2017-10           Japan        2.7
# 1        2017-09           Japan        2.8
# 2        1955-06           Japan        2.6
# 3        1955-05           Japan        2.4
# 4        1955-04           Japan        2.5
# ...          ...             ...        ...
# 4406     2016-11          Canada        6.8
# 4407     2023-05           Italy        7.8
# 4408     2023-05          France        7.4
# 4409     2023-05  United Kingdom        4.2
# 4410     2015-11   United States        5.1
#
# [4411 rows x 3 columns]

# %%
df.sort_values("TIME_PERIOD", inplace=True)
# Out:
# /var/folders/sh/s_xv2d8x6kv1_qyc9qgmkv300000gn/T/ipykernel_11070/886236120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values("TIME_PERIOD", inplace=True)

# %%
df.isnull().mean()
# Out:
# TIME_PERIOD       0.0
# Reference area    0.0
# OBS_VALUE         0.0
# dtype: float64

# %%
df.rename(columns= {"Reference area" : "country", "OBS_VALUE": "unemployment_rate" }, inplace=True)
df
# Out:
# /var/folders/sh/s_xv2d8x6kv1_qyc9qgmkv300000gn/T/ipykernel_11070/1679679949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns= {"Reference area" : "country", "OBS_VALUE": "unemployment_rate" }, inplace=True)
#      TIME_PERIOD        country  unemployment_rate
# 1245     1955-01         Canada                4.8
# 3574     1955-01  United States                4.9
# 7        1955-01          Japan                2.6
# 3573     1955-02  United States                4.7
# 6        1955-02          Japan                2.5
# ...          ...            ...                ...
# 4299     2024-08  United States                4.2
# 754      2024-08          Japan                2.5
# 3056     2024-08         France                7.5
# ...

# %%
df['country'].value_counts()
# Out:
# country
# United States     837
# Canada            836
# Japan             836
# France            500
# Italy             500
# United Kingdom    498
# Germany           404
# Name: count, dtype: int64
